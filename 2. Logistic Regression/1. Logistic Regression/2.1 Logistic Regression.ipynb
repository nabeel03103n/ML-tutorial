# %% [markdown]
# What is the Sigmoid Function?
#
# The sigmoid function is a mathematical function that maps any real-valued number to a value between 0 and 1. It is widely used in machine learning, especially in logistic regression and neural networks, because it helps model probabilities.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-3.png](attachment:image-3.png)
#
# import math
#
# def sigmoid(x):
#         return 1 / (1 + math.exp(-x))
#
# print(sigmoid(2))  # Output: 0.8807970779778823
#
#
# def logit(p):
#         return math.log(p / (1 - p))
#
# print(logit(0.88))  # Output: 2.066862759472976

# %%
import pandas as pd

df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
import matplotlib.pyplot as plt

plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df[['age']],df['bought_insurance'],test_size=0.1)

# %%
X_train.shape
# Out:
# (24, 1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 1.0
